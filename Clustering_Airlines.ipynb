# %% [markdown]
# # Clustering Airlines

# %% [markdown]
# ## Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters. Draw the inferences from the clusters obtained.

# %% [markdown]
# ## Hierarchial Clustering

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sklearn as skl 
import seaborn as sn
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
airlines = pd.read_csv("C:\\Users\\User\\Documents\\Datascience_Assignments\\Assignment 7 (Clustering)\\EastWestAirlines.csv")
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines = airlines.drop(['ID#'],axis=1)
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Normalization Function

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return x

# %%
df_norm = norm_func(airlines.iloc[:,:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Dendrogram

# %%
dendrogram = sch.dendrogram(sch.linkage(df_norm, method = 'complete'))

# %%
hc1 = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean',linkage = 'complete')

# %%
y_hc1 = hc1.fit_predict(df_norm)
y_hc1
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int64)

# %%
clusters = pd.DataFrame(y_hc1, columns = ['Clusters'])
clusters.head(10)
# Out:
#    Clusters
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
# 5         0
# 6         0
# 7         2
# 8         2
# 9         2

# %%
airlines['h_cluster_id'] = hc1.labels_
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines.value_counts('h_cluster_id')
# Out:
# h_cluster_id
# 0    2526
# 2    1144
# 1     325
# 3       4
# dtype: int64

# %%
airlines.iloc[:,:].groupby(airlines.h_cluster_id).mean()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# h_cluster_id
# 0              59791.056611   88.188836   1.703484   1.018606   1.011085
# 1             157084.578462  208.673846   4.661538   1.000000   1.061538
# 2              80173.963287  248.550699   2.104895   1.009615   1.000874
# 3             131999.500000  347.000000   2.500000   1.000000   1.000000
#
#                Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# h_cluster_id
# 0             10324.882423     9.192003         230.441013         0.672209
# 1             70477.086154    23.249231        1019.433846         3.196923
# 2             16882.864510    13.412587         739.958916         2.236888
# 3             65634.250000    69.250000       19960.000000        49.250000
#
#               Days_since_enroll    Award?
# h_cluster_id
# 0                   3824.887965  0.003167
# 1                   5770.572308  1.000000
# 2                   4304.383741  1.000000
# ...

# %% [markdown]
# ## K-means Clustering

# %%
airlines = pd.read_csv("C:\\Users\\User\\Documents\\Datascience_Assignments\\Assignment 7 (Clustering)\\EastWestAirlines.csv")
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines = airlines.drop(['ID#'],axis=1)
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_norm = norm_func(airlines.iloc[:,:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
k = list(range(2,10))
k
TWSS = [] 
for i in k:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_norm)
    WSS = [] 
    for j in range(i):
        WSS.append(sum(cdist(df_norm.iloc[kmeans.labels_==j,:],kmeans.cluster_centers_[j].reshape(1,df_norm.shape[1]),"euclidean")))
    TWSS.append(sum(WSS))

# %% [markdown]
# ### Scree plot

# %%
plt.plot(k,TWSS, 'ro-');plt.xlabel("No_of_Clusters");plt.ylabel("total_within_SS");plt.xticks(k)
# Out:
# ([<matplotlib.axis.XTick at 0x27ac410ab80>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
model = KMeans(n_clusters = 5).fit(df_norm)
model.cluster_centers_
# Out:
# array([[ 4.89953609e-02,  2.60542873e-02,  3.90044577e-02,
#          1.63447251e-02,  2.22882615e-03,  3.35642727e-02,
#          1.21825219e-01,  3.34267751e-02,  5.94073285e-02,
#          5.22892182e-01,  1.00000000e+00],
#        [ 2.92823328e-02,  8.06451613e-03,  3.05299539e-02,
#          9.79262673e-03,  2.88018433e-04,  1.31485480e-02,
#          8.03906334e-02,  7.91232441e-03,  1.37379358e-02,
#          6.71078504e-01, -3.88578059e-16],
#        [ 6.93891884e-02,  6.59020789e-03,  6.46035599e-01,
#          8.09061489e-04,  5.66343042e-03,  1.19022293e-01,
#          2.00383834e-01,  7.27197078e-03,  1.18458814e-02,
#          5.32620376e-01, -2.77555756e-16],
#        [ 6.35352962e-02,  1.77912301e-02,  7.28960396e-01,
#          6.18811881e-04,  6.49752475e-03,  1.72970238e-01,
#          2.34903868e-01,  2.31602349e-02,  4.04212591e-02,
#          5.86139300e-01,  1.00000000e+00],
#        [ 1.94137515e-02,  8.44382696e-03,  1.76841085e-02,
# ...

# %%
model.labels_ 
md = pd.Series(model.labels_)  
airlines['clust'] = md 
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines.value_counts('clust')
# Out:
# clust
# 4    1032
# 1     868
# 3     808
# 0     673
# 2     618
# dtype: int64

# %%
airlines.iloc[:,:].groupby(airlines.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0       83529.153046  290.453195   1.156018   1.032689   1.008915
# 1       49921.633641   89.903226   1.122120   1.019585   1.001152
# 2      118297.325243   73.467638   3.584142   1.001618   1.022654
# 3      108317.387376  198.336634   3.915842   1.001238   1.025990
# 4       33097.301357   94.131783   1.070736   1.016473   1.006783
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0       8850.395245    10.476969        1030.112927         3.148588
# 1       3467.074885     6.913594         243.834101         0.728111
# 2      31384.393204    17.233010         224.100324         0.627832
# 3      45609.657178    20.201733         713.728960         2.142327
# 4       3244.520349     6.173450         212.850775         0.603682
#
#        Days_since_enroll  Award?
# clust
# 0            4338.867756     1.0
# 1            5567.925115     0.0
# ...

# %% [markdown]
# ## DBSCAN Clustering

# %%
airlines = pd.read_csv("C:\\Users\\User\\Documents\\Datascience_Assignments\\Assignment 7 (Clustering)\\EastWestAirlines.csv")
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.drop(['ID#'],axis=1,inplace=True)
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
array = airlines.values
array
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]], dtype=int64)

# %%
stscaler = StandardScaler().fit(array)
X = stscaler.transform(array)

# %%
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan = DBSCAN(eps = 1, min_samples = 9)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1, min_samples=9)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl = pd.DataFrame(dbscan.labels_,columns = ['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
ds = pd.concat([airlines,cl],axis = 1)
ds
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
ds.value_counts('cluster')
# Out:
# cluster
#  0    2285
#  1    1047
# -1     656
#  2      11
# dtype: int64

# %%
ds.iloc[:,0:11].groupby(ds.cluster).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster
# -1       173941.010671  859.234756   2.670732   1.071646   1.074695
#  0        52284.891466    2.463895   1.652079   1.000000   1.000000
#  1        57730.095511    6.710602   2.576886   1.000000   1.000000
#  2        28365.363636    0.000000   1.000000   2.000000   1.000000
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster
# -1       37699.176829    21.062500        2024.500000         5.855183
#  0        8929.385120     8.366740         108.642888         0.362363
#  1       22283.531041    12.732569         251.377268         0.785100
#  2        8825.272727    11.818182          22.727273         0.181818
#
#          Days_since_enroll    Award?
# cluster
# -1             4683.217988  0.661585
#  0             3793.074836  0.000000
#  1             4490.000000  1.000000
#  2             2702.000000  0.000000

# %% [markdown]
# #### Plot Clusters

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(ds['cluster'],ds['Balance'], c = dbscan.labels_)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(ds['cluster'],ds['Qual_miles'], c = dbscan.labels_)
